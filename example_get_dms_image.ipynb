# %%
import cv2
import requests
import numpy as np
import matplotlib.pyplot as plt
import urllib.request

# %%
dms_url = 'dms.storemesh.com'
api_key_dms = 'v2Om3DVH.iKl3BUPlj0XM5qHQk9ZFxlV5ed5aYGP9'

# %% [markdown]
# ## Get image detail

# %%
json_detail = requests.get('https://{}/v1/images/{}'.format(dms_url,4090)).json() # image_uid
json_detail
# Out:
# {'file': 'http://dms.storemesh.com/media/PMD_tongue-DSC_0617.JPG',
#  'width': 3000,
#  'height': 4496}

# %%
url = json_detail['file']
file_name = url.split('/')[-1]
file_name
# Out:
# 'PMD_tongue-DSC_0617.JPG'

# %% [markdown]
# ### Request Image

# %%
req = urllib.request.urlopen(url)
arr = np.asarray(bytearray(req.read()), dtype=np.uint8)
frame = cv2.imdecode(arr, -1)
plt.imshow(frame)
